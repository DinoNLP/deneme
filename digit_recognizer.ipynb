# %%
import tensorflow as tf
from keras import layers, models

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt

def display_image(index):
    if 0 <= index < len(x_train):
        plt.figure(figsize=(3, 3))
        plt.imshow(x_train[index], cmap='gray')
        plt.title(f"Label: {y_train[index]}")
        plt.colorbar()
        plt.grid(False)
        plt.show()

# %%
display_image(3)

# %%
y_train[3]
# Out:
# 1

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(8, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 1.0050 - accuracy: 0.6543
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.7400 - accuracy: 0.7512
# Epoch 3/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6897 - accuracy: 0.7705
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6622 - accuracy: 0.7812
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6496 - accuracy: 0.7864
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6400 - accuracy: 0.7895
# Epoch 7/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6278 - accuracy: 0.7933
# Epoch 8/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6171 - accuracy: 0.7980
# Epoch 9/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6178 - accuracy: 0.7969
# Epoch 10/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6104 - accuracy: 0.8013

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
plot_history(history)

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 964us/step

# %%
y_pred = y_pred.argmax(axis=1)

# %%
import matplotlib.pyplot as plt

def display_image(index):
    if 0 <= index < len(x_train):
        print("predictions", y_pred[index])
        plt.figure(figsize=(3, 3))
        plt.imshow(x_test[index], cmap='gray')
        plt.title(f"Label: {y_test[index]}")
        plt.colorbar()
        plt.grid(False)
        plt.show()

# %%
display_image(3)
# Out:
# predictions 0

# %%
for i in range(5):
    display_image(i)
# Out:
# predictions 7
# predictions 2
# predictions 1
# predictions 0
# predictions 4
